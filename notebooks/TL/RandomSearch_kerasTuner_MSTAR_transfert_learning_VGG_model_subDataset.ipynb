# %% [markdown]
#  # SAR Target/Object Classification Using Transfert Learning

# %% [markdown]
# Using keras Tuner to find optimized hyperparameters

# %% [markdown]
# Mounting Google Drive for Cloud based Processing using GPUs

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install -q -U keras-tuner
# Out:
#      |████████████████████████████████| 71kB 3.2MB/s
#   Building wheel for keras-tuner (setup.py) ... done
#   Building wheel for terminaltables (setup.py) ... done

# %% [markdown]
# Import librairies

# %%
import sys, os
import collections
import io
import math
import time
import random
from six.moves import urllib
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
import scipy.misc as im
from sklearn.preprocessing import OneHotEncoder
from sklearn.decomposition import PCA
from skimage.transform import resize
import sklearn.metrics as sk_metrics
from skimage import data
from IPython.display import clear_output, Image, display, HTML

# %%
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential, load_model, Model
from keras.layers import Conv2D, Dense, BatchNormalization, Dropout, MaxPool2D, Flatten
from keras.metrics import categorical_accuracy
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, LearningRateScheduler, EarlyStopping
from keras.optimizers import Adam, RMSprop

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
#import tensorflow_hub as hubM
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %% [markdown]
# ## Split data on train test and Explore the images

# %%
#main_path_data = "/content/gdrive/My Drive/Colab Notebooks/"
main_path_data = "/content/gdrive/My Drive/ML-DL/Projects/ProjetHZ/Image_DL_Project-main/"

# %%
MSTAR_DIR = main_path_data + 'MSTAR-10/'+ 'train/'
os.listdir(MSTAR_DIR)
# Out:
# ['2S1',
#  'BMP2',
#  'BTR60',
#  'BRDM_2',
#  'BTR70',
#  'D7',
#  'ZIL131',
#  'ZSU_23_4',
#  'T72',
#  'T62']

# %%
def make_train_and_test_sets(input_data_dir):
  """Split the data into train and test sets and get the label classes."""
  train_examples, test_examples = [], []
  shuffler = random.Random(RANDOM_SEED)
  is_root = True
  for (dirname, subdirs, filenames) in tf.gfile.Walk(input_data_dir):
    # The root directory gives us the classes
    if is_root:
      subdirs = sorted(subdirs)
      classes = collections.OrderedDict(enumerate(subdirs))
      label_to_class = dict([(x, i) for i, x in enumerate(subdirs)])
      is_root = False
    # The sub directories give us the image files for training.
    else:
      filenames.sort()
      shuffler.shuffle(filenames)
      full_filenames = [os.path.join(dirname, f) for f in filenames]
      label = dirname.split('/')[-1]
      label_class = label_to_class[label]
      # An example is the image file and it's label class.
      examples = list(zip(full_filenames, [label_class] * len(filenames)))
      num_train = int(len(filenames) * TRAIN_FRACTION)
      train_examples.extend(examples[:num_train])
      test_examples.extend(examples[num_train:])

  shuffler.shuffle(train_examples)
  shuffler.shuffle(test_examples)
  return train_examples, test_examples, classes

# %%
RANDOM_SEED = 42
TRAIN_FRACTION = 0.8
MSTAR_TRAIN_DIR  = MSTAR_DIR
TRAIN_EXAMPLES, TEST_EXAMPLES, CLASSES = make_train_and_test_sets(input_data_dir = MSTAR_TRAIN_DIR)
NUM_CLASSES = len(CLASSES)

print('\nThe dataset has %d label classes: %s' % (NUM_CLASSES, CLASSES.values()))
print('There are %d training images' % len(TRAIN_EXAMPLES))
print('there are %d test images' % len(TEST_EXAMPLES))
# Out:
# The dataset has 10 label classes: odict_values(['2S1', 'BMP2', 'BRDM_2', 'BTR60', 'BTR70', 'D7', 'T62', 'T72', 'ZIL131', 'ZSU_23_4'])
# There are 2193 training images
# there are 553 test images

# %%
#@title Show some labeled images
def get_label(example):
  """Get the label (number) for given example."""
  return example[1]

def get_class(example):
  """Get the class (string) of given example."""
  return CLASSES[get_label(example)]

def get_encoded_image(example):
  """Get the image data (encoded jpg) of given example."""
  image_path = example[0]
  return tf.gfile.GFile(image_path, 'rb').read()

def get_image(example):
  """Get image as np.array of pixels for given example."""
  return plt.imread(io.BytesIO(get_encoded_image(example)), format='jpg')

def display_images(images_and_classes, cols=5):
  """Display given images and their labels in a grid."""
  rows = int(math.ceil(len(images_and_classes) / cols))
  fig = plt.figure()
  fig.set_size_inches(cols * 3, rows * 3)
  for i, (image, flower_class) in enumerate(images_and_classes):
    plt.subplot(rows, cols, i + 1)
    plt.axis('off')
    plt.imshow(image)
    plt.title(flower_class)

NUM_IMAGES = 20 #@param {type: 'integer'}
display_images([(get_image(example), get_class(example))
               for example in TRAIN_EXAMPLES[:NUM_IMAGES]])

# %%
def get_nb_img_color_channel(input_img_path):
  from PIL import Image
  # open image using PIL
  img = Image.open(input_img_path)
  width, height = img.size
  print(f'width, height = {(width, height)}')
  # convert to numpy array
  img = np.array(img)
  # find number of channels
  if img.ndim == 2:
      channels = 1
      print("image has 1 channel")
  else:
      channels = image.shape[-1]
      print("image has", channels, "channels")
  return width, height, channels

# %%
get_nb_img_color_channel(TRAIN_EXAMPLES[0][0])
# Out:
# width, height = (158, 158)
# image has 1 channel
# (158, 158, 1)

# %% [markdown]
# # II-Train Using Transfert Learning
# Inspired from https://github.com/Accioy/sar-10-classification/blob/master/nn.py

# %% [markdown]
# # II-1-data preparation and augmentation

# %%
def get_nb_images_of_train_val(input_folder):
  count = 0
  for i in os.listdir(input_folder):
    for j in i:
      nb_img = len(os.listdir(input_folder + '/' + i))
    count += nb_img
  return count

def compute_nb_paramters_per_layer(kernel_size, stride, nb_filter):
  return (kernel_size[0]*kernel_size[1]*stride+1)*nb_filter

# %%
input_image_size = [128,128]
#input_image_size = [224,224]

batch_size = 64
#color_mode = 'grayscale'
class_mode = 'categorical'

# %%
directory_data = os.path.join(main_path_data,'MSTAR-10','train')
#directory_val = os.path.join(main_path_data,'MSTAR-10','test')

print(directory_data)
# Out:
# /content/gdrive/My Drive/ML-DL/Projects/ProjetHZ/Image_DL_Project-main/MSTAR-10/train

# %%
# add data augmentation only for the training set 
pct_val_set = 0.2

train_generator = ImageDataGenerator(
      rotation_range=10,
      width_shift_range=0.1,
      height_shift_range=0.1,
      zoom_range=0.1,
      fill_mode='constant',
      cval=0.0,
      horizontal_flip=True,
      vertical_flip=True,
      rescale=1./255,
      validation_split=pct_val_set,
  )

val_generator = ImageDataGenerator(rescale=1./255, validation_split=pct_val_set)

print('Creation of train genarator include data augmentation ')

#val_generator = ImageDataGenerator(rescale=1./255)
print('Creation of val genarator without data augmentation (only rescale the image to normalize them) ')
# Out:
# Creation of train genarator include data augmentation
# Creation of val genarator without data augmentation (only rescale the image to normalize them)

# %%
# preparation of data train and data val before feed them to the netwrok architecture model
print('data_training'.upper())
data_training = train_generator.flow_from_directory(directory=directory_data,
                                                 target_size=input_image_size,
                                                 class_mode=class_mode ,
                                                 batch_size=batch_size,
                                                 shuffle=True,
                                                 subset = 'training')

print('data_validation'.upper())

data_validation = val_generator.flow_from_directory(directory=directory_data,
                                                   target_size=input_image_size,
                                                   class_mode=class_mode,
                                                   batch_size=batch_size,
                                                   shuffle=True,
                                                    subset = 'validation')
# Out:
# DATA_TRAINING
# Found 2203 images belonging to 10 classes.
# DATA_VALIDATION
# Found 543 images belonging to 10 classes.

# %%
for i in range(10):
  input_img_path = TRAIN_EXAMPLES[i][0]
  print(input_img_path)
  get_nb_img_color_channel(input_img_path)
# Out:
# /content/gdrive/My Drive/ML-DL/Projects/ProjetHZ/Image_DL_Project-main/MSTAR-10/train/2S1/hb19935.jpeg
# width, height = (158, 158)
# image has 1 channel
# /content/gdrive/My Drive/ML-DL/Projects/ProjetHZ/Image_DL_Project-main/MSTAR-10/train/BTR60/hb03819.jpeg
# width, height = (128, 128)
# image has 1 channel
# /content/gdrive/My Drive/ML-DL/Projects/ProjetHZ/Image_DL_Project-main/MSTAR-10/train/BMP2/hb03880.jpeg
# width, height = (128, 128)
# image has 1 channel
# /content/gdrive/My Drive/ML-DL/Projects/ProjetHZ/Image_DL_Project-main/MSTAR-10/train/BMP2/hb03829.jpeg
# width, height = (128, 128)
# image has 1 channel
# /content/gdrive/My Drive/ML-DL/Projects/ProjetHZ/Image_DL_Project-main/MSTAR-10/train/BTR70/hb04025.jpeg
# width, height = (128, 128)
# image has 1 channel
# /content/gdrive/My Drive/ML-DL/Projects/ProjetHZ/Image_DL_Project-main/MSTAR-10/train/BTR60/hb03965.jpeg
# width, height = (128, 128)
# image has 1 channel
# /content/gdrive/My Drive/ML-DL/Projects/ProjetHZ/Image_DL_Project-main/MSTAR-10/train/BMP2/hb04003.jpeg
# width, height = (128, 128)
# image has 1 channel
# /content/gdrive/My Drive/ML-DL/Projects/ProjetHZ/Image_DL_Project-main/MSTAR-10/train/BRDM_2/hb19951.jpeg
# width, height = (128, 129)
# image has 1 channel
# /content/gdrive/My Drive/ML-DL/Projects/ProjetHZ/Image_DL_Project-main/MSTAR-10/train/ZIL131/hb19559.jpeg
# width, height = (192, 193)
# image has 1 channel
# /content/gdrive/My Drive/ML-DL/Projects/ProjetHZ/Image_DL_Project-main/MSTAR-10/train/ZSU_23_4/hb19923.jpeg
# width, height = (158, 158)
# image has 1 channel

# %%
# print index and name of training classes 
data_training.class_indices
# Out:
# {'2S1': 0,
#  'BMP2': 1,
#  'BRDM_2': 2,
#  'BTR60': 3,
#  'BTR70': 4,
#  'D7': 5,
#  'T62': 6,
#  'T72': 7,
#  'ZIL131': 8,
#  'ZSU_23_4': 9}

# %%
# print index and name of validation classes 
data_validation.class_indices
# Out:
# {'2S1': 0,
#  'BMP2': 1,
#  'BRDM_2': 2,
#  'BTR60': 3,
#  'BTR70': 4,
#  'D7': 5,
#  'T62': 6,
#  'T72': 7,
#  'ZIL131': 8,
#  'ZSU_23_4': 9}

# %% [markdown]
# **Get the train and val size and Define the number of step per epoch**

# %%
'''
train_size = get_nb_images_of_train_val(directory_train)
val_size = get_nb_images_of_train_val(directory_val)
print(f'Nb TRAIN images = {train_size} \nNb VAL images = {val_size}')
print(f'pct of TRAIN images = {np.round(train_size/(train_size+val_size),2)} \npct of VAL images = {np.round(val_size/(train_size+val_size),2)}')
step_train_per_epoch = train_size//batch_size
step_val_per_epoch = val_size//batch_size
print(f'Nb Train steps per epoch = {step_train_per_epoch}\nNb Val steps per epoch = {step_val_per_epoch}')
'''


train_size0 = get_nb_images_of_train_val(directory_data)
train_size = (1-pct_val_set)*train_size0
val_size = (pct_val_set)*train_size0

step_train_per_epoch = train_size//batch_size
step_val_per_epoch = val_size//batch_size

print(f'Nb Train steps per epoch = {step_train_per_epoch}\nNb Val steps per epoch = {step_val_per_epoch}')

#print(train_size)
# Out:
# Nb Train steps per epoch = 34.0
# Nb Val steps per epoch = 8.0

# %% [markdown]
# # II-2-Build architecture by transfert learning from exiting architecture

# %% [markdown]
# **A-Fine tunning using VGG 16**

# %% [markdown]
# tf.keras.applications.InceptionV3(
#                                   include_top=True,
#                                   weights="imagenet",
#                                   input_tensor=None,
#                                   input_shape=None,
#                                   pooling=None,
#                                   classes=1000,
#                                   classifier_activation="softmax",
#                               )

# %%
from keras import optimizers

# %%
#vgg16_model = keras.applications.vgg16.VGG16(include_top=True, weights='imagenet', 
#    input_shape=(input_image_size[0],input_image_size[1],3), pooling='max')

vgg19_model = keras.applications.vgg19.VGG19(include_top=False, weights='imagenet', 
    input_shape=(input_image_size[0],input_image_size[1],3))

vgg19_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step
# Model: "vgg19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 128, 128, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 128, 128, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 64, 64, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 64, 64, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 64, 64, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 32, 32, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 32, 32, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 16, 16, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 16, 16, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 8, 8, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow import keras
from tensorflow.keras import layers
from kerastuner.tuners import RandomSearch

#define the model-building function. It takes an argument hp from which you can sample hyperparameters
#and the base model on which we are building the TL
'''
def build_model(hp):
  base_model = keras.applications.vgg19.VGG19(include_top=False, weights='imagenet', 
    input_shape=(input_image_size[0],input_image_size[1],3))
  
  x=base_model.output
  x=Flatten()(x)
  x=Dense(units=hp.Int('units',min_value=1024,max_value=4096,step=32),activation = 'relu')(x)
  x=Dropout(0.3)(x)

  predict=Dense(10, activation = 'softmax')(x)
  model=Model(inputs=base_model.input, outputs=predict)
  adam=optimizers.Adam(lr=0.01, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
  model.compile(loss='categorical_crossentropy',
                optimizer=keras.optimizers.Adam(hp.Choice('learning_rate',values=[1e-2, 1e-3, 1e-4])),
                metrics=['categorical_accuracy'])
  return model


'''
def build_model(hp):
  base_model = keras.applications.vgg19.VGG19(include_top=False, weights='imagenet', 
    input_shape=(input_image_size[0],input_image_size[1],3))
  
  for layer in base_model.layers:
      layer.trainable = False

  x=base_model.output
  x=Flatten()(x)
  for i in range(hp.Int('num_layers', 2, 4)):
    #x=Dense(units=hp.Int('units_' + str(i),min_value=1024,max_value=4096,step=32),activation = 'relu')(x)
    x=Dense(units=hp.Int('units_' + str(i),min_value=256,max_value=1024,step=32),activation = 'relu')(x)

    #x=Dropout(0.3)(x)

  predict=Dense(10, activation = 'softmax')(x)
  model=Model(inputs=base_model.input, outputs=predict)
  adam=optimizers.Adam(lr=0.01, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
  model.compile(loss='categorical_crossentropy',
                optimizer=keras.optimizers.Adam(hp.Choice('learning_rate',values=[1e-2, 1e-3, 1e-4])),
                metrics=['categorical_accuracy'])
  return model

# %% [markdown]
# Next, instantiate a tuner. Specify the total number of trials (max_trials) to test, and the number of models that should be built and fit for each trial (executions_per_trial).

# %%
tuner = RandomSearch(
    build_model,
    objective='categorical_accuracy',
    max_trials=5,
    executions_per_trial=2,
    directory='main_path_data',
    project_name='KerasTunerBasics')

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 4
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 2, 'max_value': 4, 'step': 1, 'sampling': None}
# units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 256, 'max_value': 1024, 'step': 32, 'sampling': None}
# units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 256, 'max_value': 1024, 'step': 32, 'sampling': None}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}

# %%
''' en cours: voir comment faire avec kerasTumer + data generator
https://www.google.com/search?q=keras+tuner+data+generator&rlz=1C1GCEU_frFR837FR837&oq=keras+tuner+data+generator&aqs=chrome..69i57.4770j0j7&sourceid=chrome&ie=UTF-8
'''

tuner.search(data_training,
             epochs=50,
             validation_data=data_validation)
'''
tuner.search(x, y,
             epochs=5,
             validation_data=(val_x, val_y))

history = model.fit_generator(generator=data_training,
                    validation_data=data_validation,
                    use_multiprocessing=False,
                    steps_per_epoch=step_train_per_epoch,
                    epochs=nb_epochs,
                    validation_steps=step_val_per_epoch,
                    verbose=1,
                    callbacks=callbacks_list)

'''
# Out:
# Search: Running Trial #1
#
# Hyperparameter    |Value             |Best Value So Far
# num_layers        |4                 |?
# units_0           |736               |?
# units_1           |256               |?
# learning_rate     |0.0001            |?
#
# Epoch 1/50
# 35/35 [==============================] - ETA: 0s - batch: 17.0000 - size: 62.9429 - loss: 2.2576 - categorical_accuracy: 0.1698
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 35/35 [==============================] - 609s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 2.2576 - categorical_accuracy: 0.1698 - val_loss: 2.1404 - val_categorical_accuracy: 0.1878
# Epoch 2/50
# 35/35 [==============================] - 578s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 2.0387 - categorical_accuracy: 0.2347 - val_loss: 1.8582 - val_categorical_accuracy: 0.3959
# Epoch 3/50
# 35/35 [==============================] - 584s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 1.8113 - categorical_accuracy: 0.3150 - val_loss: 1.6797 - val_categorical_accuracy: 0.3591
# Epoch 4/50
# 35/35 [==============================] - 582s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 1.6756 - categorical_accuracy: 0.3709 - val_loss: 1.5557 - val_categorical_accuracy: 0.4236
# Epoch 5/50
# 35/35 [==============================] - 589s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 1.5729 - categorical_accuracy: 0.4126 - val_loss: 1.5622 - val_categorical_accuracy: 0.3794
# Epoch 6/50
# 35/35 [==============================] - 584s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 1.4962 - categorical_accuracy: 0.4462 - val_loss: 1.5776 - val_categorical_accuracy: 0.3646
# Epoch 7/50
# 35/35 [==============================] - 586s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 1.4383 - categorical_accuracy: 0.4462 - val_loss: 1.4617 - val_categorical_accuracy: 0.3683
# Epoch 8/50
# 35/35 [==============================] - 584s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 1.3367 - categorical_accuracy: 0.5052 - val_loss: 1.4510 - val_categorical_accuracy: 0.4162
# Epoch 9/50
# 35/35 [==============================] - 580s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 1.2471 - categorical_accuracy: 0.5524 - val_loss: 1.4053 - val_categorical_accuracy: 0.4457
# Epoch 10/50
# 35/35 [==============================] - 583s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 1.2011 - categorical_accuracy: 0.5502 - val_loss: 1.2387 - val_categorical_accuracy: 0.5028
# Epoch 11/50
# 35/35 [==============================] - 582s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 1.1554 - categorical_accuracy: 0.5788 - val_loss: 1.4115 - val_categorical_accuracy: 0.4217
# Epoch 12/50
# 35/35 [==============================] - 582s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 1.1591 - categorical_accuracy: 0.5656 - val_loss: 1.2927 - val_categorical_accuracy: 0.4936
# Epoch 13/50
# 35/35 [==============================] - 587s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 1.1040 - categorical_accuracy: 0.5874 - val_loss: 1.7009 - val_categorical_accuracy: 0.3499
# Epoch 14/50
# 35/35 [==============================] - 584s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 1.0410 - categorical_accuracy: 0.6173 - val_loss: 1.3071 - val_categorical_accuracy: 0.4880
# Epoch 15/50
# 35/35 [==============================] - 590s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 1.0024 - categorical_accuracy: 0.6246 - val_loss: 1.2004 - val_categorical_accuracy: 0.5249
# Epoch 16/50
# 35/35 [==============================] - 586s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.9792 - categorical_accuracy: 0.6296 - val_loss: 1.1285 - val_categorical_accuracy: 0.5580
# Epoch 17/50
# 35/35 [==============================] - 581s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.9688 - categorical_accuracy: 0.6414 - val_loss: 1.6073 - val_categorical_accuracy: 0.3959
# Epoch 18/50
# 35/35 [==============================] - 582s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.9382 - categorical_accuracy: 0.6400 - val_loss: 1.3678 - val_categorical_accuracy: 0.4604
# Epoch 19/50
# 35/35 [==============================] - 585s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.9015 - categorical_accuracy: 0.6627 - val_loss: 1.5464 - val_categorical_accuracy: 0.4254
# Epoch 20/50
# 35/35 [==============================] - 584s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.8844 - categorical_accuracy: 0.6668 - val_loss: 1.2821 - val_categorical_accuracy: 0.4788
# Epoch 21/50
# 35/35 [==============================] - 584s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.8834 - categorical_accuracy: 0.6773 - val_loss: 1.6841 - val_categorical_accuracy: 0.4052
# Epoch 22/50
# 35/35 [==============================] - 589s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.8661 - categorical_accuracy: 0.6768 - val_loss: 1.3448 - val_categorical_accuracy: 0.5083
# Epoch 23/50
# 35/35 [==============================] - 583s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.8217 - categorical_accuracy: 0.6922 - val_loss: 1.5806 - val_categorical_accuracy: 0.4641
# Epoch 24/50
# 35/35 [==============================] - 580s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.8190 - categorical_accuracy: 0.6836 - val_loss: 1.6440 - val_categorical_accuracy: 0.3812
# Epoch 25/50
# 35/35 [==============================] - 581s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.8183 - categorical_accuracy: 0.6777 - val_loss: 1.7452 - val_categorical_accuracy: 0.4180
# Epoch 26/50
# 35/35 [==============================] - 579s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.7812 - categorical_accuracy: 0.7077 - val_loss: 1.4065 - val_categorical_accuracy: 0.5009
# Epoch 27/50
# 35/35 [==============================] - 580s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.7760 - categorical_accuracy: 0.7145 - val_loss: 1.8084 - val_categorical_accuracy: 0.3959
# Epoch 28/50
# 35/35 [==============================] - 583s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.7782 - categorical_accuracy: 0.7036 - val_loss: 1.6690 - val_categorical_accuracy: 0.4365
# Epoch 29/50
# 35/35 [==============================] - 583s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.8029 - categorical_accuracy: 0.6859 - val_loss: 1.3455 - val_categorical_accuracy: 0.5212
# Epoch 30/50
# 35/35 [==============================] - 583s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.7635 - categorical_accuracy: 0.7190 - val_loss: 1.2760 - val_categorical_accuracy: 0.5433
# Epoch 31/50
# 35/35 [==============================] - 582s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.7189 - categorical_accuracy: 0.7458 - val_loss: 1.6909 - val_categorical_accuracy: 0.4475
# Epoch 32/50
# 35/35 [==============================] - 581s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.7585 - categorical_accuracy: 0.7090 - val_loss: 1.6648 - val_categorical_accuracy: 0.4641
# Epoch 33/50
# 35/35 [==============================] - 579s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.7455 - categorical_accuracy: 0.7172 - val_loss: 1.1861 - val_categorical_accuracy: 0.6077
# Epoch 34/50
# 35/35 [==============================] - 578s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.7549 - categorical_accuracy: 0.7045 - val_loss: 1.4089 - val_categorical_accuracy: 0.4862
# Epoch 35/50
# 35/35 [==============================] - 576s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.7241 - categorical_accuracy: 0.7249 - val_loss: 1.2666 - val_categorical_accuracy: 0.5322
# Epoch 36/50
# 35/35 [==============================] - 577s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.6527 - categorical_accuracy: 0.7626 - val_loss: 1.5205 - val_categorical_accuracy: 0.4862
# Epoch 37/50
# 35/35 [==============================] - 575s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.6592 - categorical_accuracy: 0.7508 - val_loss: 1.7485 - val_categorical_accuracy: 0.4457
# Epoch 38/50
# 35/35 [==============================] - 573s 16s/step - batch: 17.0000 - size: 62.9429 - loss: 0.6870 - categorical_accuracy: 0.7331 - val_loss: 1.7658 - val_categorical_accuracy: 0.4199
# Epoch 39/50
# 35/35 [==============================] - 573s 16s/step - batch: 17.0000 - size: 62.9429 - loss: 0.6844 - categorical_accuracy: 0.7367 - val_loss: 1.7836 - val_categorical_accuracy: 0.4162
# Epoch 40/50
# 35/35 [==============================] - 573s 16s/step - batch: 17.0000 - size: 62.9429 - loss: 0.6288 - categorical_accuracy: 0.7626 - val_loss: 1.6828 - val_categorical_accuracy: 0.4383
# Epoch 41/50
# 35/35 [==============================] - 573s 16s/step - batch: 17.0000 - size: 62.9429 - loss: 0.6763 - categorical_accuracy: 0.7340 - val_loss: 1.6855 - val_categorical_accuracy: 0.4751
# Epoch 42/50
# 35/35 [==============================] - 575s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.6491 - categorical_accuracy: 0.7667 - val_loss: 1.8565 - val_categorical_accuracy: 0.4346
# Epoch 43/50
# 35/35 [==============================] - 580s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.6469 - categorical_accuracy: 0.7585 - val_loss: 1.7740 - val_categorical_accuracy: 0.4549
# Epoch 44/50
# 35/35 [==============================] - 577s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.6165 - categorical_accuracy: 0.7712 - val_loss: 1.7364 - val_categorical_accuracy: 0.4475
# Epoch 45/50
# 35/35 [==============================] - 581s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.6170 - categorical_accuracy: 0.7708 - val_loss: 1.1102 - val_categorical_accuracy: 0.5967
# Epoch 46/50
# 35/35 [==============================] - 582s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.6746 - categorical_accuracy: 0.7485 - val_loss: 1.6215 - val_categorical_accuracy: 0.4696
# Epoch 47/50
# 35/35 [==============================] - 581s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.6070 - categorical_accuracy: 0.7758 - val_loss: 2.0541 - val_categorical_accuracy: 0.3849
# Epoch 48/50
# 35/35 [==============================] - 577s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.6417 - categorical_accuracy: 0.7581 - val_loss: 1.9835 - val_categorical_accuracy: 0.4180
# Epoch 49/50
# 35/35 [==============================] - 575s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.6153 - categorical_accuracy: 0.7685 - val_loss: 2.2909 - val_categorical_accuracy: 0.3702
# Epoch 50/50
# 35/35 [==============================] - 575s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.5826 - categorical_accuracy: 0.7726 - val_loss: 1.7534 - val_categorical_accuracy: 0.4438
# Epoch 1/50
# 35/35 [==============================] - 579s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 2.2725 - categorical_accuracy: 0.1430 - val_loss: 2.1791 - val_categorical_accuracy: 0.2173
# Epoch 2/50
# 35/35 [==============================] - 575s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 2.0731 - categorical_accuracy: 0.2692 - val_loss: 1.9297 - val_categorical_accuracy: 0.3057
# Epoch 3/50
# 35/35 [==============================] - 581s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 1.8417 - categorical_accuracy: 0.3450 - val_loss: 1.7556 - val_categorical_accuracy: 0.3168
# Epoch 4/50
# 35/35 [==============================] - 588s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 1.6777 - categorical_accuracy: 0.3672 - val_loss: 1.6356 - val_categorical_accuracy: 0.3389
# Epoch 5/50
# 35/35 [==============================] - 590s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 1.5697 - categorical_accuracy: 0.4149 - val_loss: 1.5163 - val_categorical_accuracy: 0.4236
# Epoch 6/50
# 35/35 [==============================] - 590s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 1.4730 - categorical_accuracy: 0.4517 - val_loss: 1.4448 - val_categorical_accuracy: 0.4180
# Epoch 7/50
# 35/35 [==============================] - 590s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 1.4018 - categorical_accuracy: 0.4884 - val_loss: 1.5200 - val_categorical_accuracy: 0.4052
# Epoch 8/50
# 35/35 [==============================] - 586s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 1.2914 - categorical_accuracy: 0.5352 - val_loss: 1.5763 - val_categorical_accuracy: 0.3757
# Epoch 9/50
# 35/35 [==============================] - 585s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 1.2515 - categorical_accuracy: 0.5406 - val_loss: 1.6288 - val_categorical_accuracy: 0.3610
# Epoch 10/50
# 35/35 [==============================] - 585s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 1.1719 - categorical_accuracy: 0.5647 - val_loss: 1.2468 - val_categorical_accuracy: 0.4917
# Epoch 11/50
# 35/35 [==============================] - 585s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 1.1300 - categorical_accuracy: 0.5819 - val_loss: 1.2616 - val_categorical_accuracy: 0.4678
# Epoch 12/50
# 35/35 [==============================] - 587s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 1.0972 - categorical_accuracy: 0.5987 - val_loss: 1.4523 - val_categorical_accuracy: 0.4604
# Epoch 13/50
# 35/35 [==============================] - 585s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 1.0878 - categorical_accuracy: 0.5919 - val_loss: 1.4776 - val_categorical_accuracy: 0.4052
# Epoch 14/50
# 35/35 [==============================] - 590s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 1.0571 - categorical_accuracy: 0.5878 - val_loss: 1.2535 - val_categorical_accuracy: 0.5175
# Epoch 15/50
# 35/35 [==============================] - 585s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.9775 - categorical_accuracy: 0.6364 - val_loss: 1.4408 - val_categorical_accuracy: 0.4512
# Epoch 16/50
# 35/35 [==============================] - 585s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 1.0176 - categorical_accuracy: 0.5933 - val_loss: 1.4117 - val_categorical_accuracy: 0.4880
# Epoch 17/50
# 35/35 [==============================] - 583s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.9315 - categorical_accuracy: 0.6500 - val_loss: 1.3018 - val_categorical_accuracy: 0.4991
# Epoch 18/50
# 35/35 [==============================] - 583s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.9304 - categorical_accuracy: 0.6564 - val_loss: 1.6263 - val_categorical_accuracy: 0.4033
# Epoch 19/50
# 35/35 [==============================] - 585s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.8937 - categorical_accuracy: 0.6632 - val_loss: 1.4452 - val_categorical_accuracy: 0.4512
# Epoch 20/50
# 35/35 [==============================] - 585s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.8881 - categorical_accuracy: 0.6627 - val_loss: 1.3793 - val_categorical_accuracy: 0.4770
# Epoch 21/50
# 35/35 [==============================] - 584s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.8642 - categorical_accuracy: 0.6682 - val_loss: 2.0771 - val_categorical_accuracy: 0.3573
# Epoch 22/50
# 35/35 [==============================] - 584s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.8672 - categorical_accuracy: 0.6618 - val_loss: 1.5808 - val_categorical_accuracy: 0.4659
# Epoch 23/50
# 35/35 [==============================] - 584s 17s/step - batch: 17.0000 - size: 62.9429 - loss: 0.8097 - categorical_accuracy: 0.6954 - val_loss: 1.2470 - val_categorical_accuracy: 0.5451
# Epoch 24/50
#  6/35 [====>.........................] - ETA: 6:35 - batch: 2.5000 - size: 64.0000 - loss: 0.7547 - categorical_accuracy: 0.7135

# %% [markdown]
# Convert from Keras engine model to a sequential model for ease of use

# %%
x=vgg19_model.output
x=Flatten()(x)
x=Dense(4096,activation = 'relu')(x)
x=Dropout(0.3)(x)
x=Dense(4096,activation = 'relu')(x)
#x=Dense(4096,activation = 'relu')(x)
x=Dropout(0.3)(x)
predict=Dense(10, activation = 'softmax')(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c4e2bdc1d545> in <module>()
# ----> 1 x=vgg19_model.output
#       2 x=Flatten()(x)
#       3 x=Dense(4096,activation = 'relu')(x)
#       4 x=Dropout(0.3)(x)
#       5 x=Dense(4096,activation = 'relu')(x)
#
# NameError: name 'vgg19_model' is not defined

# %%
model=Model(inputs=vgg19_model.input, outputs=predict)
adam=optimizers.Adam(lr=0.01, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model.compile(loss='categorical_crossentropy',optimizer=adam,metrics=['categorical_accuracy'])

print('#of layers for VGG16 model : ',len(vgg19_model.layers))
print('#of layers for custom model(VGG16+Dense1024+predictSoftmax10): ',len(model.layers))
model.summary()
# Out:
# #of layers for VGG16 model :  22
# #of layers for custom model(VGG16+Dense1024+predictSoftmax10):  28
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 128, 128, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 128, 128, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 64, 64, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 64, 64, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 64, 64, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 32, 32, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 32, 32, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 16, 16, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 16, 16, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 8, 8, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              33558528
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                40970
# =================================================================
# Total params: 70,405,194
# Trainable params: 70,405,194
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils import  plot_model
#plot_model(vgg16_model)

# %%
sys.path.append(main_path_data + 'data_prep')

# %%
import datetime
date_object = datetime.date.today()
date_object = str(date_object).replace('-','_')

# %%
path_to_save_model = main_path_data + f'trained_models/{date_object}'

model_path = path_to_save_model  + f'/mstar_vgg19_{date_object}_' + '{epoch:02d}-{val_acc:.2f}.hdf5'
model_path
# Out:
# '/content/gdrive/My Drive/ML-DL/Projects/ProjetHZ/Image_DL_Project-main/trained_models/2021_04_29/mstar_vgg19_2021_04_29_{epoch:02d}-{val_acc:.2f}.hdf5'

# %% [markdown]
# **Freeze layers**

# %%
def show_trainble_layers(model_name):
  for i, layer in enumerate(model_name.layers):
    print(i,layer.name,layer.trainable)
    

for layer in model.layers[:-2]:
    layer.trainable = False
show_trainble_layers(model_name=model)
# Out:
# 0 input_1 False
# 1 block1_conv1 False
# 2 block1_conv2 False
# 3 block1_pool False
# 4 block2_conv1 False
# 5 block2_conv2 False
# 6 block2_pool False
# 7 block3_conv1 False
# 8 block3_conv2 False
# 9 block3_conv3 False
# 10 block3_conv4 False
# 11 block3_pool False
# 12 block4_conv1 False
# 13 block4_conv2 False
# 14 block4_conv3 False
# 15 block4_conv4 False
# 16 block4_pool False
# 17 block5_conv1 False
# 18 block5_conv2 False
# 19 block5_conv3 False
# 20 block5_conv4 False
# 21 block5_pool False
# 22 flatten False
# 23 dense False
# 24 dropout False
# 25 dense_1 False
# 26 dropout_1 True
# 27 dense_2 True

# %% [markdown]
# # II-3-Launch training:
#
# *   Define the hyperparameters of training : lr, optimizer
#
# 1.   compile the model
# 2.   fit the model

# %%
lr = 1e-3
decacy = 0
nb_epochs = 20

# %%
from keras.callbacks import CSVLogger

csv_logger = CSVLogger('training.log', separator=',', append=False)

# model callbeck list and save option 
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=0.00001,verbose=1)

# keep the best checkpoint
checkpoint = ModelCheckpoint(model_path, monitor='val_acc', verbose=1, mode='auto',save_best_only=True) 

# stop training when the accuracy does not continue improvement
early_stopping_monitor = EarlyStopping(monitor='val_acc',min_delta=0,patience=5,verbose=0, mode='auto')

callbacks_list = [checkpoint, reduce_lr, csv_logger]

# %%
# define the optimizer
#adam=optimizers.Adam(lr=0.01, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
adam = Adam(lr=lr, decay=decacy) 
rmsprop = RMSprop(lr=lr, decay=decacy)

# %%
# compile the model
#model.compile(loss='categorical_crossentropy',optimizer=adam,metrics=['categorical_accuracy'])
model.compile(loss='categorical_crossentropy',optimizer=adam,metrics=['accuracy'])

# %%
# Launch training 
history = model.fit_generator(generator=data_training,
                    validation_data=data_validation,
                    use_multiprocessing=False,
                    steps_per_epoch=step_train_per_epoch,
                    epochs=nb_epochs,
                    validation_steps=step_val_per_epoch,
                    verbose=1,
                    callbacks=callbacks_list)

#save history for latter viz
import pandas as pd
log_data = pd.read_csv('training.log', sep=',', engine='python')

path_to_save_model = main_path_data + f'trained_models/{date_object}'
LogName = 'historyLog_1024_DP03'
path_Log= f'{path_to_save_model}/{LogName}'+'.csv' 
log_data.to_csv (path_Log, index = False, header=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training_v1.py:1240: UserWarning: `model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`model.fit_generator` is deprecated and '
# Epoch 1/20
# 34/34 [==============================] - ETA: 0s - batch: 16.5000 - size: 62.9118 - loss: 2.4320 - acc: 0.1071
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# Epoch 00001: val_acc improved from -inf to 0.16406, saving model to /content/gdrive/My Drive/ML-DL/Projects/ProjetHZ/Image_DL_Project-main/trained_models/2021_04_28/mstar_vgg19_2021_04_28_01-0.16.hdf5
# 34/34 [==============================] - 603s 18s/step - batch: 16.5000 - size: 62.9118 - loss: 2.4320 - acc: 0.1071 - val_loss: 2.2756 - val_acc: 0.1641
# Epoch 2/20
# 34/34 [==============================] - ETA: 0s - batch: 16.5000 - size: 62.9118 - loss: 2.3423 - acc: 0.1351
# Epoch 00002: val_acc did not improve from 0.16406
# 34/34 [==============================] - 557s 16s/step - batch: 16.5000 - size: 62.9118 - loss: 2.3423 - acc: 0.1351 - val_loss: 2.2057 - val_acc: 0.1621
# Epoch 3/20
# 34/34 [==============================] - ETA: 0s - batch: 16.5000 - size: 62.9118 - loss: 2.3187 - acc: 0.1491
# Epoch 00003: val_acc improved from 0.16406 to 0.25000, saving model to /content/gdrive/My Drive/ML-DL/Projects/ProjetHZ/Image_DL_Project-main/trained_models/2021_04_28/mstar_vgg19_2021_04_28_03-0.25.hdf5
# 34/34 [==============================] - 555s 16s/step - batch: 16.5000 - size: 62.9118 - loss: 2.3187 - acc: 0.1491 - val_loss: 2.1933 - val_acc: 0.2500
# Epoch 4/20
# 34/34 [==============================] - ETA: 0s - batch: 16.5000 - size: 62.9118 - loss: 2.2859 - acc: 0.1599
# Epoch 00004: val_acc did not improve from 0.25000
# 34/34 [==============================] - 556s 16s/step - batch: 16.5000 - size: 62.9118 - loss: 2.2859 - acc: 0.1599 - val_loss: 2.1296 - val_acc: 0.1875
# Epoch 5/20
# 34/34 [==============================] - ETA: 0s - batch: 16.5000 - size: 64.0000 - loss: 2.2191 - acc: 0.1857
# Epoch 00005: val_acc did not improve from 0.25000
# 34/34 [==============================] - 563s 17s/step - batch: 16.5000 - size: 64.0000 - loss: 2.2191 - acc: 0.1857 - val_loss: 2.1226 - val_acc: 0.1348
# Epoch 6/20
# 34/34 [==============================] - ETA: 0s - batch: 16.5000 - size: 61.8235 - loss: 2.1945 - acc: 0.1860
# Epoch 00006: val_acc did not improve from 0.25000
# 34/34 [==============================] - 548s 16s/step - batch: 16.5000 - size: 61.8235 - loss: 2.1945 - acc: 0.1860 - val_loss: 2.1209 - val_acc: 0.1953
# Epoch 7/20
# 34/34 [==============================] - ETA: 0s - batch: 16.5000 - size: 62.9118 - loss: 2.1637 - acc: 0.2020
# Epoch 00007: val_acc improved from 0.25000 to 0.30859, saving model to /content/gdrive/My Drive/ML-DL/Projects/ProjetHZ/Image_DL_Project-main/trained_models/2021_04_28/mstar_vgg19_2021_04_28_07-0.31.hdf5
# 34/34 [==============================] - 556s 16s/step - batch: 16.5000 - size: 62.9118 - loss: 2.1637 - acc: 0.2020 - val_loss: 2.0775 - val_acc: 0.3086
# Epoch 8/20
# 34/34 [==============================] - ETA: 0s - batch: 16.5000 - size: 62.9118 - loss: 2.1652 - acc: 0.1973
# Epoch 00008: val_acc improved from 0.30859 to 0.33594, saving model to /content/gdrive/My Drive/ML-DL/Projects/ProjetHZ/Image_DL_Project-main/trained_models/2021_04_28/mstar_vgg19_2021_04_28_08-0.34.hdf5
# 34/34 [==============================] - 560s 17s/step - batch: 16.5000 - size: 62.9118 - loss: 2.1652 - acc: 0.1973 - val_loss: 2.0626 - val_acc: 0.3359
# Epoch 9/20
# 34/34 [==============================] - ETA: 0s - batch: 16.5000 - size: 62.9118 - loss: 2.1193 - acc: 0.2319
# Epoch 00009: val_acc did not improve from 0.33594
# 34/34 [==============================] - 561s 17s/step - batch: 16.5000 - size: 62.9118 - loss: 2.1193 - acc: 0.2319 - val_loss: 2.0400 - val_acc: 0.2246
# Epoch 10/20
# 34/34 [==============================] - ETA: 0s - batch: 16.5000 - size: 64.0000 - loss: 2.1268 - acc: 0.2123
# Epoch 00010: val_acc did not improve from 0.33594
# 34/34 [==============================] - 562s 17s/step - batch: 16.5000 - size: 64.0000 - loss: 2.1268 - acc: 0.2123 - val_loss: 2.0142 - val_acc: 0.2402
# Epoch 11/20
# 34/34 [==============================] - ETA: 0s - batch: 16.5000 - size: 61.8235 - loss: 2.0892 - acc: 0.2379
# Epoch 00011: val_acc improved from 0.33594 to 0.36133, saving model to /content/gdrive/My Drive/ML-DL/Projects/ProjetHZ/Image_DL_Project-main/trained_models/2021_04_28/mstar_vgg19_2021_04_28_11-0.36.hdf5
# 34/34 [==============================] - 549s 16s/step - batch: 16.5000 - size: 61.8235 - loss: 2.0892 - acc: 0.2379 - val_loss: 2.0100 - val_acc: 0.3613
# Epoch 12/20
# 34/34 [==============================] - ETA: 0s - batch: 16.5000 - size: 62.9118 - loss: 2.0495 - acc: 0.2300
# Epoch 00012: val_acc improved from 0.36133 to 0.42188, saving model to /content/gdrive/My Drive/ML-DL/Projects/ProjetHZ/Image_DL_Project-main/trained_models/2021_04_28/mstar_vgg19_2021_04_28_12-0.42.hdf5
# 34/34 [==============================] - 561s 16s/step - batch: 16.5000 - size: 62.9118 - loss: 2.0495 - acc: 0.2300 - val_loss: 1.9215 - val_acc: 0.4219
# Epoch 13/20
# 34/34 [==============================] - ETA: 0s - batch: 16.5000 - size: 62.9118 - loss: 2.0563 - acc: 0.2417
# Epoch 00013: val_acc did not improve from 0.42188
# 34/34 [==============================] - 559s 17s/step - batch: 16.5000 - size: 62.9118 - loss: 2.0563 - acc: 0.2417 - val_loss: 1.9672 - val_acc: 0.3652
# Epoch 14/20
# 34/34 [==============================] - ETA: 0s - batch: 16.5000 - size: 64.0000 - loss: 2.0375 - acc: 0.2491
# Epoch 00014: val_acc did not improve from 0.42188
# 34/34 [==============================] - 568s 17s/step - batch: 16.5000 - size: 64.0000 - loss: 2.0375 - acc: 0.2491 - val_loss: 1.9063 - val_acc: 0.2812
# Epoch 15/20
# 34/34 [==============================] - ETA: 0s - batch: 16.5000 - size: 61.8235 - loss: 2.0322 - acc: 0.2436
# Epoch 00015: val_acc did not improve from 0.42188
# 34/34 [==============================] - 548s 16s/step - batch: 16.5000 - size: 61.8235 - loss: 2.0322 - acc: 0.2436 - val_loss: 1.8921 - val_acc: 0.3125
# Epoch 16/20
# 34/34 [==============================] - ETA: 0s - batch: 16.5000 - size: 62.9118 - loss: 1.9978 - acc: 0.2581
# Epoch 00016: val_acc did not improve from 0.42188
# 34/34 [==============================] - 558s 16s/step - batch: 16.5000 - size: 62.9118 - loss: 1.9978 - acc: 0.2581 - val_loss: 1.9236 - val_acc: 0.2852
# Epoch 17/20
# 34/34 [==============================] - ETA: 0s - batch: 16.5000 - size: 64.0000 - loss: 2.0446 - acc: 0.2403
# Epoch 00017: val_acc did not improve from 0.42188
# 34/34 [==============================] - 563s 17s/step - batch: 16.5000 - size: 64.0000 - loss: 2.0446 - acc: 0.2403 - val_loss: 1.9052 - val_acc: 0.3262
# Epoch 18/20
# 34/34 [==============================] - ETA: 0s - batch: 16.5000 - size: 62.9118 - loss: 2.0129 - acc: 0.2417
# Epoch 00018: val_acc did not improve from 0.42188
# 34/34 [==============================] - 556s 17s/step - batch: 16.5000 - size: 62.9118 - loss: 2.0129 - acc: 0.2417 - val_loss: 1.9016 - val_acc: 0.2871
# Epoch 19/20
# 34/34 [==============================] - ETA: 0s - batch: 16.5000 - size: 62.9118 - loss: 2.0095 - acc: 0.2496
# Epoch 00019: val_acc did not improve from 0.42188
# 34/34 [==============================] - 556s 16s/step - batch: 16.5000 - size: 62.9118 - loss: 2.0095 - acc: 0.2496 - val_loss: 1.8402 - val_acc: 0.3867
# Epoch 20/20
# 34/34 [==============================] - ETA: 0s - batch: 16.5000 - size: 61.8235 - loss: 2.0107 - acc: 0.2498
# Epoch 00020: val_acc did not improve from 0.42188
# 34/34 [==============================] - 549s 16s/step - batch: 16.5000 - size: 61.8235 - loss: 2.0107 - acc: 0.2498 - val_loss: 1.9021 - val_acc: 0.3105

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'acc', 'val_loss', 'val_acc', 'lr'])

# %%
len(history.history)
# Out:
# 5

# %%
#save history for latter viz
import pandas as pd
log_data = pd.read_csv('training.log', sep=',', engine='python')

selected_logName = 'mstar_vgg19_2021_04_28_11-0.59'
path_selectedLog= f'{path_to_save_model}/{selected_logName}'+'.csv' 
#csv_file_name = 
log_data.to_csv (path_selectedLog, index = False, header=True)

# %%
print('max acc',np.max(history.history['acc']))
print('max val_acc',np.max(history.history['val_acc']))

print('max loss',np.max(history.history['loss']))
print('max val_loss',np.max(history.history['val_loss']))
# Out:
# max acc 0.6930147
# max val_acc 0.6171875
# max loss 2.8915719407470832
# max val_loss 1.996235191822052

# %% [markdown]
# model.fit_generator(generator=data_train,epochs=100,
#     validation_data=data_validation)
# model.save('mstar10.h5')

# %% [markdown]
# # **III-Anlysis of model performances**

# %% [markdown]
# **Plot historay training**

# %%
#plot accuracy
plt.figure(figsize=(8,6))
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy', fontsize=16)
plt.ylabel('accuracy', fontsize=16)
plt.xlabel('epoch', fontsize=16)
plt.legend(['acc: train', 'acc: val'], loc='upper left', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %%
#plot loss
plt.figure(figsize=(8,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss', fontsize=16)
plt.ylabel('loss', fontsize=16)
plt.xlabel('epoch', fontsize=16)
plt.legend(['loss: train', 'loss: val'], loc='upper left', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# **Make prediction of all validation set**

# %%
path_to_save_model = main_path_data + 'trained_models/2021_04_28'

#selected_model_name = 'mstar_vgg19_2021_04_25_14-0.64.hdf5'
#selected_model_name = 'mstar_vgg19_2021_04_28_11-0.59.hdf5'
selected_model_name = 'mstar_vgg19_2021_04_28_12-0.42.hdf5'
path_selected_model = f'{path_to_save_model}/{selected_model_name}' 
print(f'Prediction using inference model: {path_selected_model}')
# Out:
# Prediction using inference model: /content/gdrive/My Drive/ML-DL/Projects/ProjetHZ/Image_DL_Project-main/trained_models/2021_04_28/mstar_vgg19_2021_04_28_12-0.42.hdf5

# %%
print(path_selected_model)
# Out:
# /content/gdrive/My Drive/ML-DL/Projects/ProjetHZ/Image_DL_Project-main/trained_models/2021_04_28/mstar_vgg19_2021_04_28_12-0.42.hdf5

# %%
inference_model = load_model(path_selected_model)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
inference_model.layers[0].input_shape
# Out:
# [(None, 128, 128, 3)]

# %%
# generate the test set images

test_generator = ImageDataGenerator(rescale=1./255, validation_split=pct_val_set)

data_test = val_generator.flow_from_directory(directory=directory_data,
                                                   target_size=input_image_size,
                                                   class_mode=class_mode,
                                                   batch_size=batch_size,
                                                   shuffle=False,
                                                   subset = 'validation') 
'''
test_generator = ImageDataGenerator(rescale=1./255)

data_test = test_generator.flow_from_directory(directory=directory_val,
    target_size=[128,128],class_mode='categorical',
    batch_size=32,shuffle=False)
print(data_test.class_indices)
'''




#color_mode='grayscale'
# Out:
# Found 543 images belonging to 10 classes.
# "\ntest_generator = ImageDataGenerator(rescale=1./255)\n\ndata_test = test_generator.flow_from_directory(directory=directory_val,\n    target_size=[128,128],class_mode='categorical',\n    batch_size=32,shuffle=False)\nprint(data_test.class_indices)\n"

# %%
import time
start = time.time()
evaluation = inference_model.evaluate_generator(data_test)

end = time.time()
print(f"Runtime of the program is {end - start}")
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training_v1.py:1273: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# Runtime of the program is 126.92417740821838

# %%
print(evaluation)
# Out:
# [1.8857700162463717, 0.427256]

# %%
os.listdir(directory_val)

# %%
picturePath = directory_val + '/'+ 'BTR60' + '/'
os.listdir(picturePath)[0]
picturePath = picturePath + os.listdir(picturePath)[20]
picturePath

# %%
img_width = 128
img_height = 128

# %%
index_class_val_set = data_validation.class_indices
index_class_val_set
# Out:
# {'2S1': 0,
#  'BMP2': 1,
#  'BRDM_2': 2,
#  'BTR60': 3,
#  'BTR70': 4,
#  'D7': 5,
#  'T62': 6,
#  'T72': 7,
#  'ZIL131': 8,
#  'ZSU_23_4': 9}

# %%
image_path = picturePath
img = image.load_img(image_path, target_size=(img_width, img_height), color_mode="grayscale")
plt.imshow(img, cmap='gray')
img = image.img_to_array(img)
img = np.expand_dims(img, axis=0)
result = inference_model.predict(img)
plt.title(result)
plt.show()

# %% [markdown]
# **Plot Confusion matrix**

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
#Confution Matrix and Classification Report
Y_pred = inference_model.predict_generator(data_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training_v1.py:1301: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '

# %%
len(Y_pred)
# Out:
# 543

# %%
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
cm = confusion_matrix(data_test.classes, y_pred)
print(cm)
# Out:
# Confusion Matrix
# [[19  0 15 15  0  0  5  5  0  0]
#  [ 6  0  7 22  0  0  0 11  0  0]
#  [ 0  0 41  1  0  0  5  3  1  8]
#  [ 0  0  2 37  0  0  1  8  0  3]
#  [ 3  0  8 26  0  0  0  7  0  2]
#  [ 0  0  0  0  0  0  8  0  1 50]
#  [ 1  0  1  0  0  0 21  2  1 33]
#  [ 0  0  0  9  0  0  1 32  0  4]
#  [ 0  0  0  0  0  0  6  0 24 29]
#  [ 0  0  0  0  0  0  1  0  0 58]]

# %%
target_names = list(index_class_val_set.keys())
print(target_names)
# Out:
# ['2S1', 'BMP2', 'BRDM_2', 'BTR60', 'BTR70', 'D7', 'T62', 'T72', 'ZIL131', 'ZSU_23_4']

# %%
def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):
    """
    given a sklearn confusion matrix (cm), make a nice plot

    Arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html
                  plt.get_cmap('jet') or plt.cm.Blues

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions

    Usage
    -----
    plot_confusion_matrix(cm           = cm,                  # confusion matrix created by
                                                              # sklearn.metrics.confusion_matrix
                          normalize    = True,                # show proportions
                          target_names = y_labels_vals,       # list of names of the classes
                          title        = best_estimator_name) # title of graph

    Citiation
    ---------
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

    """
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(10, 12))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()

# %%
# plot the confusion matrix
plot_confusion_matrix(cm, target_names, title='Confusion matrix', cmap=None, normalize=False)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def make_confusion_matrix(cf,
                          group_names=None,
                          categories='auto',
                          count=True,
                          percent=True,
                          cbar=True,
                          xyticks=True,
                          xyplotlabels=True,
                          sum_stats=True,
                          figsize=None,
                          cmap='Blues',
                          title=None):
    '''
    This function will make a pretty plot of an sklearn Confusion Matrix cm using a Seaborn heatmap visualization.

    Arguments
    ---------
    cf:            confusion matrix to be passed in

    group_names:   List of strings that represent the labels row by row to be shown in each square.

    categories:    List of strings containing the categories to be displayed on the x,y axis. Default is 'auto'

    count:         If True, show the raw number in the confusion matrix. Default is True.

    normalize:     If True, show the proportions for each category. Default is True.

    cbar:          If True, show the color bar. The cbar values are based off the values in the confusion matrix.
                   Default is True.

    xyticks:       If True, show x and y ticks. Default is True.

    xyplotlabels:  If True, show 'True Label' and 'Predicted Label' on the figure. Default is True.

    sum_stats:     If True, display summary statistics below the figure. Default is True.

    figsize:       Tuple representing the figure size. Default will be the matplotlib rcParams value.

    cmap:          Colormap of the values displayed from matplotlib.pyplot.cm. Default is 'Blues'
                   See http://matplotlib.org/examples/color/colormaps_reference.html
                   
    title:         Title for the heatmap. Default is None.

    '''


    # CODE TO GENERATE TEXT INSIDE EACH SQUARE
    blanks = ['' for i in range(cf.size)]

    if group_names and len(group_names)==cf.size:
        group_labels = ["{}\n".format(value) for value in group_names]
    else:
        group_labels = blanks

    if count:
        group_counts = ["{0:0.0f}\n".format(value) for value in cf.flatten()]
    else:
        group_counts = blanks

    if percent:
        group_percentages = ["{0:.2%}".format(value) for value in cf.flatten()/np.sum(cf)]
    else:
        group_percentages = blanks

    box_labels = [f"{v1}{v2}{v3}".strip() for v1, v2, v3 in zip(group_labels,group_counts,group_percentages)]
    box_labels = np.asarray(box_labels).reshape(cf.shape[0],cf.shape[1])


    # CODE TO GENERATE SUMMARY STATISTICS & TEXT FOR SUMMARY STATS
    if sum_stats:
        #Accuracy is sum of diagonal divided by total observations
        accuracy  = np.trace(cf) / float(np.sum(cf))

        #if it is a binary confusion matrix, show some more stats
        if len(cf)==2:
            #Metrics for Binary Confusion Matrices
            precision = cf[1,1] / sum(cf[:,1])
            recall    = cf[1,1] / sum(cf[1,:])
            f1_score  = 2*precision*recall / (precision + recall)
            stats_text = "\n\nAccuracy={:0.3f}\nPrecision={:0.3f}\nRecall={:0.3f}\nF1 Score={:0.3f}".format(
                accuracy,precision,recall,f1_score)
        else:
            stats_text = "\n\nAccuracy={:0.3f}".format(accuracy)
    else:
        stats_text = ""


    # SET FIGURE PARAMETERS ACCORDING TO OTHER ARGUMENTS
    if figsize==None:
        #Get default figure size if not set
        figsize = plt.rcParams.get('figure.figsize')

    if xyticks==False:
        #Do not show categories if xyticks is False
        categories=False


    # MAKE THE HEATMAP VISUALIZATION
    plt.figure(figsize=figsize)
    sns.heatmap(cf,annot=box_labels,fmt="",cmap=cmap,cbar=cbar,xticklabels=categories,yticklabels=categories)

    if xyplotlabels:
        plt.ylabel('True label')
        plt.xlabel('Predicted label' + stats_text)
    else:
        plt.xlabel(stats_text)
    
    if title:
        plt.title(title)

# %%
make_confusion_matrix(cm,
                          group_names=None,
                          categories=target_names,
                          count=True,
                          percent=False,
                          cbar=True,
                          xyticks=True,
                          xyplotlabels=True,
                          sum_stats=True,
                          figsize=(12,10),
                          cmap='Blues',
                          title=None)

# %%
print('Classification Report')
print(classification_report(data_validation.classes, y_pred, target_names=target_names))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#          2S1       0.40      0.86      0.54        59
#         BMP2       1.00      0.04      0.08        46
#       BRDM_2       0.65      0.86      0.74        59
#        BTR60       1.00      0.02      0.04        51
#        BTR70       0.42      0.28      0.34        46
#           D7       0.48      0.93      0.63        59
#          T62       0.85      0.39      0.53        59
#          T72       0.59      0.76      0.67        46
#       ZIL131       0.83      0.88      0.85        59
#     ZSU_23_4       1.00      0.63      0.77        59
#
#     accuracy                           0.59       543
#    macro avg       0.72      0.57      0.52       543
# weighted avg       0.72      0.59      0.54       543
